# %% [markdown]
# # BCI Giuseppe Bonomo BCI2b IV

# %%
#%%
#!git clone https://github.com/marco-siino/EEG-ATCNet.git
#!git clone https://github.com/Bonomo31/Tesi.git
# %pip install mne
# %pip install PyWavelets
#Le ulitme versioni non sono compatibili con le librerie usate
#in preprocess_HGD.py, quindi si è optato a utilizzare una versione meno recente
#%pip install braindecode==0.3

import os
import sys
import shutil
import time
import pywt
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import scipy.signal as signal


from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
from sklearn.metrics import cohen_kappa_score
from sklearn.model_selection import train_test_split
#os.chdir("/content/Tesi/BCI2b_IV/")
#os.chdir("/Users/giuseppebonomo/Desktop/Tesi/BCI2b_IV/")
os.chdir("/home/giuseppe_bonomo/DATASET/BCI2b_IV/")


import models

from preprocess import get_data
#from keras.utils.vis_utils import plot_model
# Out:
# Requirement already satisfied: mne in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (1.9.0)
# Requirement already satisfied: decorator in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from mne) (5.2.1)
# Requirement already satisfied: jinja2 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.6 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from mne) (3.10.1)
# Requirement already satisfied: numpy<3,>=1.23 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from mne) (2.1.3)
# Requirement already satisfied: packaging in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from mne) (24.2)
# Requirement already satisfied: pooch>=1.5 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.9 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from mne) (1.15.2)
# Requirement already satisfied: tqdm in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from mne) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from matplotlib>=3.6->mne) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from matplotlib>=3.6->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from matplotlib>=3.6->mne) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from matplotlib>=3.6->mne) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from matplotlib>=3.6->mne) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from matplotlib>=3.6->mne) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from matplotlib>=3.6->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from pooch>=1.5->mne) (4.3.7)
# Requirement already satisfied: requests>=2.19.0 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from pooch>=1.5->mne) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: six>=1.5 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mne) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: PyWavelets in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (1.8.0)
# Requirement already satisfied: numpy<3,>=1.23 in /home/giuseppe_bonomo/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from PyWavelets) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# 2025-08-07 08:13:29.716458: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-07 08:13:29.726277: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754547209.737609 4024871 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754547209.740784 4024871 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1754547209.748957 4024871 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754547209.748970 4024871 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754547209.748971 4024871 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754547209.748972 4024871 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-07 08:13:29.752078: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Organize the dataset.

# %%
import os
import requests
import zipfile

# Creare la cartella "dataset" se non è già presente
os.makedirs("dataset", exist_ok=True)

# Percorso del file GDF e ZIP
gdf_path = "/Users/Giuseppe/Desktop/Tesi/codice/Tesi/BCI2b_IV/dataset/B0101T.gdf"
zip_path = "dataset/BCI2b.zip"

# Scaricare il dataset nella cartella "dataset" se non è già presente
if not os.path.exists(gdf_path):
    url = "https://www.bbci.de/competition/download/competition_iv/BCICIV_2b_gdf.zip"
    print("Scaricamento del dataset in corso...")
    
    # Scaricare il file ZIP
    response = requests.get(url)
    with open(zip_path, "wb") as f:
        f.write(response.content)
    
    print("Estrazione dei file...")
    # Estrarre i file nella cartella "dataset"
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        zip_ref.extractall("dataset")
    
    # Rimuovere il file .zip
    os.remove(zip_path)
    print("Dataset scaricato ed estratto con successo.")
else:
    print("Dataset già scaricato.")
# Out:
# Scaricamento del dataset in corso...
# Estrazione dei file...
# Dataset scaricato ed estratto con successo.

# %%
"""# Creare la cartella "dataset" se non è già presente (MacOS)
os.makedirs("dataset", exist_ok=True)

# Scaricare il dataset nella cartella "dataset" se non è già presente
if not os.path.exists("dataset/B0101T.gdf"):
    # !wget -O dataset/BCI2b.zip "https://www.bbci.de/competition/download/competition_iv/BCICIV_2b_gdf.zip"
        
    # Estrarre i file nella cartella "dataset"
    # !unzip dataset/BCI2b.zip -d dataset

    # Rimuovere il file .zip
    os.remove("dataset/BCI2b.zip")
else:
    print("Dataset già scaricato")"""
# Out:
# '# Creare la cartella "dataset" se non è già presente (MacOS)\nos.makedirs("dataset", exist_ok=True)\n\n# Scaricare il dataset nella cartella "dataset" se non è già presente\nif not os.path.exists("dataset/B0101T.gdf"):\n    !wget -O dataset/BCI2b.zip "https://www.bbci.de/competition/download/competition_iv/BCICIV_2b_gdf.zip"\n        \n    # Estrarre i file nella cartella "dataset"\n    !unzip dataset/BCI2b.zip -d dataset\n\n    # Rimuovere il file .zip\n    os.remove("dataset/BCI2b.zip")\nelse:\n    print("Dataset già scaricato")'

# %% [markdown]
# # Functions definitions

# %%
#%%
def draw_learning_curves(history, sub):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy - subject: ' + str(sub))
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'val'], loc='upper left')
    plt.show()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss - subject: ' + str(sub))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'val'], loc='upper left')
    plt.show()
    plt.close()

def draw_confusion_matrix(cf_matrix, sub, results_path, classes_labels):
    # Generate confusion matrix plot
    display_labels = classes_labels
    disp = ConfusionMatrixDisplay(confusion_matrix=cf_matrix,
                                display_labels=display_labels)
    disp.plot()
    disp.ax_.set_xticklabels(display_labels, rotation=12)
    plt.title('Confusion Matrix of Subject: ' + sub )
    plt.savefig(results_path + '/subject_' + sub + '.png')
    plt.show()

def draw_performance_barChart(num_sub, metric, label):
    fig, ax = plt.subplots()
    x = list(range(1, num_sub+1))
    ax.bar(x, metric, 0.5, label=label)
    ax.set_ylabel(label)
    ax.set_xlabel("Subject")
    ax.set_xticks(x)
    ax.set_title('Model '+ label + ' per subject')
    ax.set_ylim([0,1])

# %% [markdown]
# # Preprocessing functions definition

# %% [markdown]
# ## DB4 (Soft -> Threshold 5.5)

# %%
def db4_soft(signal, wavelet='db4', level=4, threshold=5.5):
    """
    Applica la RDWT (Discrete Wavelet Transform) al segnale e lo ricostruisce,
    rimuovendo i coefficienti di dettaglio sotto una certa soglia per enfatizzare
    le caratteristiche principali del segnale.

    Args:
    - signal: il segnale da elaborare
    - wavelet: tipo di wavelet da utilizzare (default 'db4')
    - level: livello della decomposizione (default 4)
    - threshold: soglia per i coefficienti di dettaglio (default 0.5)

    Returns:
    - Il segnale ricostruito dopo la manipolazione della RDWT
    """


    print("Lunghezza originale:", signal.shape[-1])  # Dovrebbe essere 1125
    coeffs = pywt.wavedec(signal, wavelet, mode='per', level=level)
    print("Lunghezza coefficiente di approssimazione:", len(coeffs[0]))

    reconstructed_signal = pywt.waverec(coeffs, wavelet, mode='per')
    print("Lunghezza ricostruita:", len(reconstructed_signal))

    # Decomposizione del segnale in coefficienti
    coeffs = pywt.wavedec(signal, wavelet, mode='per', level=level)

    # Modifica i coefficienti di dettaglio
    # Si applica un threshold sui coefficienti di dettaglio per "ridurre" la componente di alta frequenza
    coeffs_thresholded = [coeffs[0]]  # Mantieni il coefficiente di approssimazione
    for i in range(1, len(coeffs)):
        coeffs_thresholded.append(np.where(np.abs(coeffs[i]) < threshold, 0, coeffs[i]))

    # Ricostruzione del segnale dai coefficienti modificati
    reconstructed_signal = pywt.waverec(coeffs_thresholded, wavelet, mode='per')

    # Taglia il segnale ricostruito per mantenerne la stessa lunghezza dell'input
    return reconstructed_signal[:len(signal)]

# %% [markdown]
# ## DB4 (Hard -> Threshold 10.5)

# %%
def db4_hard(signal, wavelet='db4', level=4, threshold=10.5):
    """
    Applica la RDWT (Discrete Wavelet Transform) al segnale e lo ricostruisce,
    rimuovendo i coefficienti di dettaglio sotto una certa soglia per enfatizzare
    le caratteristiche principali del segnale.

    Args:
    - signal: il segnale da elaborare
    - wavelet: tipo di wavelet da utilizzare (default 'db4')
    - level: livello della decomposizione (default 4)
    - threshold: soglia per i coefficienti di dettaglio (default 0.5)

    Returns:
    - Il segnale ricostruito dopo la manipolazione della RDWT
    """

    # Decomposizione del segnale in coefficienti
    coeffs = pywt.wavedec(signal, wavelet, mode='per', level=level)

    # Modifica i coefficienti di dettaglio
    # Si applica un threshold sui coefficienti di dettaglio per "ridurre" la componente di alta frequenza
    coeffs_thresholded = [coeffs[0]]  # Mantieni il coefficiente di approssimazione
    for i in range(1, len(coeffs)):
        coeffs_thresholded.append(np.where(np.abs(coeffs[i]) < threshold, 0, coeffs[i]))

    # Ricostruzione del segnale dai coefficienti modificati
    reconstructed_signal = pywt.waverec(coeffs_thresholded, wavelet, mode='per')

    # Taglia il segnale ricostruito per mantenerne la stessa lunghezza dell'input
    return reconstructed_signal[:len(signal)]

# %% [markdown]
# ## RDWT

# %%
def rational_dilated_wavelet_transform(sig, wavelet='db4', levels=4, dilation_factors=None, threshold=5.5):
    """
    Applica la Rational Dilated Wavelet Transform (RDWT) a un segnale EEG multidimensionale.

    Args:
    - sig: array numpy di forma (eventi, 1, canali, campioni)
    - wavelet: tipo di wavelet da utilizzare (default 'db4')
    - levels: numero di livelli di decomposizione (default 4)
    - dilation_factors: lista di fattori di dilatazione razionale (default: [3/2, 5/3, 7/4, ...])
    - threshold: soglia per i coefficienti di dettaglio (default 5.5)

    Returns:
    - Segnale ricostruito con la RDWT (stessa dimensione dell'input)
    """
    eventi, _, canali, campioni = sig.shape
    print("Lunghezza originale del segnale:", sig.shape)

    if dilation_factors is None:
        dilation_factors = [3/2, 5/3, 7/4, 9/5]

    coeffs_approx = sig.copy()  # Inizializza con il segnale originale
    detail_coeffs = []

    for i in range(levels):
        factor = dilation_factors[i]
        wavelet_filter = pywt.Wavelet(wavelet)
        lo_d, hi_d = wavelet_filter.dec_lo, wavelet_filter.dec_hi

        # Ridimensionamento dei filtri
        lo_d = signal.resample(lo_d, int(len(lo_d) * factor))
        hi_d = signal.resample(hi_d, int(len(hi_d) * factor))

        print(f"Livello {i+1}: coeffs_approx shape {coeffs_approx.shape}, lo_d shape {lo_d.shape}, hi_d shape {hi_d.shape}")

        approx = np.zeros_like(coeffs_approx)
        detail = np.zeros_like(coeffs_approx)

        # Applica la convoluzione per ogni canale EEG
        for e in range(eventi):
            for c in range(canali):
                approx[e, 0, c, :] = np.convolve(coeffs_approx[e, 0, c, :], lo_d, mode='same')
                detail[e, 0, c, :] = np.convolve(coeffs_approx[e, 0, c, :], hi_d, mode='same')

                # Soglia sui coefficienti di dettaglio
                detail[e, 0, c, np.abs(detail[e, 0, c, :]) < threshold] = 0

        detail_coeffs.append(detail)
        coeffs_approx = approx  # Passa l'approssimazione al livello successivo

    # Ricostruzione del segnale
    reconstructed = coeffs_approx.copy()
    for i in range(levels-1, -1, -1):
        reconstructed += detail_coeffs[i]

    print("Lunghezza del segnale ricostruito:", reconstructed.shape)
    return reconstructed

# %% [markdown]
# # RDWT normalized with min-max

# %%
def normalize_min_max(sig, reconstructed):
    """
    Normalizza il segnale ricostruito usando la normalizzazione Min-Max,
    riportandolo alla scala del segnale di input.

    Args:
    - sig: array numpy di forma (eventi, 1, canali, campioni), segnale di input
    - reconstructed: array numpy di forma (eventi, 1, canali, campioni), segnale ricostruito

    Returns:
    - Segnale ricostruito normalizzato sulla scala dell'input
    """
    min_input = np.min(sig, axis=-1, keepdims=True)
    max_input = np.max(sig, axis=-1, keepdims=True)

    min_reconstructed = np.min(reconstructed, axis=-1, keepdims=True)
    max_reconstructed = np.max(reconstructed, axis=-1, keepdims=True)

    # Evita la divisione per zero
    range_reconstructed = max_reconstructed - min_reconstructed
    range_reconstructed[range_reconstructed == 0] = 1

    normalized = (reconstructed - min_reconstructed) / range_reconstructed

    # Riporta alla scala originale
    scaled = normalized * (max_input - min_input) + min_input

    return scaled

# %% [markdown]
# # Apply Preprocessing

# %%
def apply_preprocessing (signals_data, preprocessing):
  if preprocessing=="none":
    return signals_data
  elif preprocessing=="db4_soft":
    return db4_soft(signals_data)
  elif preprocessing=="db4_hard":
    return db4_hard(signals_data)
  elif preprocessing=="rdwt":
    return rational_dilated_wavelet_transform(signals_data)
  elif preprocessing=="rdwt_normalized":
    reconstructed = rational_dilated_wavelet_transform(signals_data)
    return normalize_min_max(signals_data, reconstructed)

# %% [markdown]
# # Model training function

# %%
#%% Training
def train(dataset_conf, train_conf, results_path):

    # remove the 'result' folder before training
    if os.path.exists(results_path):
        # Remove the folder and its contents
        shutil.rmtree(results_path)
        os.makedirs(results_path)

    # Get the current 'IN' time to calculate the overall training time
    in_exp = time.time()
    # Create a file to store the path of the best model among several runs
    best_models = open(results_path + "/best models RockNetB.txt", "w")
    # Create a file to store performance during training
    log_write = open(results_path + "/log RockNetB.txt", "w")

    # Get dataset parameters
    dataset = dataset_conf.get('name')
    n_sub = dataset_conf.get('n_sub')
    data_path = dataset_conf.get('data_path')
    isStandard = dataset_conf.get('isStandard')
    LOSO = dataset_conf.get('LOSO')
    # Get training hyperparamters
    batch_size = train_conf.get('batch_size')
    epochs = train_conf.get('epochs')
    signal_preprocessing = dataset_conf.get('signal_preprocessing')
    patience = train_conf.get('patience')
    lr = train_conf.get('lr')
    LearnCurves = train_conf.get('LearnCurves') # Plot Learning Curves?
    n_train = train_conf.get('n_train')
    model_name = train_conf.get('model')
    from_logits = train_conf.get('from_logits')

    # Initialize variables
    acc = np.zeros((n_sub, n_train))
    kappa = np.zeros((n_sub, n_train))

    # Iteration over subjects
    # for sub in range(n_sub-1, n_sub): # (num_sub): for all subjects, (i-1,i): for the ith subject.
    for sub in range(n_sub): # (num_sub): for all subjects, (i-1,i): for the ith subject.

        print('\nTraining on subject ', sub+1)
        log_write.write( '\nTraining on subject '+ str(sub+1) +'\n')
        # Initiating variables to save the best subject accuracy among multiple runs.
        BestSubjAcc = 0
        bestTrainingHistory = []

        # Get training and validation data
        X_train, _, y_train_onehot, _, _, _ = get_data(
            data_path, sub, dataset, LOSO = LOSO, isStandard = isStandard)

        # Divide the training data into training and validation
        X_train, X_val, y_train_onehot, y_val_onehot = train_test_split(X_train, y_train_onehot, test_size=0.2, random_state=42)


        print("\n\nBefore preprocessing X_train shape is:"+str(X_train.shape))
        print("Before preprocessing X_val shape is:"+str(X_val.shape))
        
        X_train = apply_preprocessing(X_train, preprocessing=signal_preprocessing)
        X_val = apply_preprocessing(X_val, preprocessing=signal_preprocessing)
        
        print("\n\nAfter preprocessing X_train shape is:"+str(X_train.shape))
        print("After preprocessing X_val shape is:"+str(X_val.shape))


        # Iteration over multiple runs
        for train in range(n_train): # How many repetitions of training for subject i.
            # Set the random seed for TensorFlow and NumPy random number generator.
            # The purpose of setting a seed is to ensure reproducibility in random operations.
            tf.random.set_seed(train+1)
            np.random.seed(train+1)

            # Get the current 'IN' time to calculate the 'run' training time
            in_run = time.time()

            # Create folders and files to save trained models for all runs
            filepath = results_path + '/saved models/run-{}'.format(train+1)
            if not os.path.exists(filepath):
                os.makedirs(filepath)
            filepath = filepath + '/subject-{}.weights.h5'.format(sub+1)

            # Create the model
            model = getModel(model_name, dataset_conf, from_logits)
            # Compile and train the model
            model.compile(loss=CategoricalCrossentropy(from_logits=from_logits), optimizer=Adam(learning_rate=lr), metrics=['accuracy'])

            # model.summary()
            # plot_model(model, to_file='plot_model.png', show_shapes=True, show_layer_names=True)

            callbacks = [
                ModelCheckpoint(filepath, monitor='val_loss', verbose=0,
                                save_best_only=True, save_weights_only=True, mode='min'),
                ReduceLROnPlateau(monitor="val_loss", factor=0.90, patience=20, verbose=0, min_lr=0.0001),
                # EarlyStopping(monitor='val_loss', verbose=1, mode='min', patience=patience)
            ]
            history = model.fit(X_train, y_train_onehot, validation_data=(X_val, y_val_onehot),
                                epochs=epochs, batch_size=batch_size, callbacks=callbacks, verbose=0)

            # Evaluate the performance of the trained model based on the validation data
            # Here we load the Trained weights from the file saved in the hard
            # disk, which should be the same as the weights of the current model.
            model.load_weights(filepath)
            y_pred = model.predict(X_val)

            if from_logits:
                y_pred = tf.nn.softmax(y_pred).numpy().argmax(axis=-1)
            else:
                y_pred = y_pred.argmax(axis=-1)

            labels = y_val_onehot.argmax(axis=-1)
            acc[sub, train]  = accuracy_score(labels, y_pred)
            kappa[sub, train] = cohen_kappa_score(labels, y_pred)

            # Get the current 'OUT' time to calculate the 'run' training time
            out_run = time.time()
            # Print & write performance measures for each run
            info = 'Subject: {}   seed {}   time: {:.1f} m   '.format(sub+1, train+1, ((out_run-in_run)/60))
            info = info + 'valid_acc: {:.4f}   valid_loss: {:.3f}'.format(acc[sub, train], min(history.history['val_loss']))
            print(info)
            log_write.write(info +'\n')
            # If current training run is better than previous runs, save the history.
            if(BestSubjAcc < acc[sub, train]):
                 BestSubjAcc = acc[sub, train]
                 bestTrainingHistory = history

        # Store the path of the best model among several runs
        best_run = np.argmax(acc[sub,:])
        filepath = '/saved models/run-{}/subject-{}.h5'.format(best_run+1, sub+1)+'\n'
        best_models.write(filepath)

        # Plot Learning curves
        if (LearnCurves == True):
            print('Plot Learning Curves ....... ')
            draw_learning_curves(bestTrainingHistory, sub+1)

    # Get the current 'OUT' time to calculate the overall training time
    out_exp = time.time()

    # Print & write the validation performance using all seeds
    head1 = head2 = '         '
    for sub in range(n_sub):
        head1 = head1 + 'sub_{}   '.format(sub+1)
        head2 = head2 + '-----   '
    head1 = head1 + '  average'
    head2 = head2 + '  -------'
    info = '\n---------------------------------\nValidation performance (acc %):'
    info = info + '\n---------------------------------\n' + head1 +'\n'+ head2
    for run in range(n_train):
        info = info + '\nSeed {}:  '.format(run+1)
        for sub in range(n_sub):
            info = info + '{:.2f}   '.format(acc[sub, run]*100)
        info = info + '  {:.2f}   '.format(np.average(acc[:, run])*100)
    info = info + '\n---------------------------------\nAverage acc - all seeds: '
    info = info + '{:.2f} %\n\nTrain Time  - all seeds: {:.1f}'.format(np.average(acc)*100, (out_exp-in_exp)/(60))
    info = info + ' min\n---------------------------------\n'
    print(info)
    log_write.write(info+'\n')

    # Close open files
    best_models.close()
    log_write.close()

# %% [markdown]
# # Evaluation function

# %%
#%% Evaluation
def test(model, dataset_conf, results_path, allRuns = True):
    # Open the  "Log" file to write the evaluation results
    log_write = open(results_path + "/log RockNetB.txt", "a")

    # Get dataset paramters
    dataset = dataset_conf.get('name')
    signal_preprocessing = dataset_conf.get('signal_preprocessing')
    n_classes = dataset_conf.get('n_classes')
    n_sub = dataset_conf.get('n_sub')
    data_path = dataset_conf.get('data_path')
    isStandard = dataset_conf.get('isStandard')
    LOSO = dataset_conf.get('LOSO')
    classes_labels = dataset_conf.get('cl_labels')
    #Ripetuto
    #signal_preprocessing = dataset_conf.get('signal_preprocessing')

    # Test the performance based on several runs (seeds)
    runs = os.listdir(results_path+"/saved models")
    # Initialize variables
    acc = np.zeros((n_sub, len(runs)))
    kappa = np.zeros((n_sub, len(runs)))
    cf_matrix = np.zeros([n_sub, len(runs), n_classes, n_classes])

    # Iteration over subjects
    # for sub in range(n_sub-1, n_sub): # (num_sub): for all subjects, (i-1,i): for the ith subject.
    inference_time = 0 #  inference_time: classification time for one trial
    for sub in range(n_sub): # (num_sub): for all subjects, (i-1,i): for the ith subject.
        # Load data
        _, _, _, X_test, _, y_test_onehot = get_data(data_path, sub, dataset, LOSO = LOSO, isStandard = isStandard)

        X_test = apply_preprocessing(X_test, preprocessing=signal_preprocessing)

        # Iteration over runs (seeds)
        for seed in range(len(runs)):
            # Load the model of the seed.
            model.load_weights('{}/saved models/{}/subject-{}.weights.h5'.format(results_path, runs[seed], sub+1))

            inference_time = time.time()
            # Predict MI task
            y_pred = model.predict(X_test).argmax(axis=-1)
            inference_time = (time.time() - inference_time)/X_test.shape[0]
            # Calculate accuracy and K-score
            labels = y_test_onehot.argmax(axis=-1)
            acc[sub, seed]  = accuracy_score(labels, y_pred)
            kappa[sub, seed] = cohen_kappa_score(labels, y_pred)
            # Calculate and draw confusion matrix
            cf_matrix[sub, seed, :, :] = confusion_matrix(labels, y_pred, normalize='true')
            # draw_confusion_matrix(cf_matrix[sub, seed, :, :], str(sub+1), results_path, classes_labels)

    # Print & write the average performance measures for all subjects
    head1 = head2 = '                  '
    for sub in range(n_sub):
        head1 = head1 + 'sub_{}   '.format(sub+1)
        head2 = head2 + '-----   '
    head1 = head1 + '  average'
    head2 = head2 + '  -------'
    info = '\n' + head1 +'\n'+ head2
    info = '\n---------------------------------\nTest performance (acc & k-score):\n'
    info = info + '---------------------------------\n' + head1 +'\n'+ head2
    for run in range(len(runs)):
        info = info + '\nSeed {}: '.format(run+1)
        info_acc = '(acc %)   '
        info_k = '        (k-sco)   '
        for sub in range(n_sub):
            info_acc = info_acc + '{:.2f}   '.format(acc[sub, run]*100)
            info_k = info_k + '{:.3f}   '.format(kappa[sub, run])
        info_acc = info_acc + '  {:.2f}   '.format(np.average(acc[:, run])*100)
        info_k = info_k + '  {:.3f}   '.format(np.average(kappa[:, run]))
        info = info + info_acc + '\n' + info_k
    info = info + '\n----------------------------------\nAverage - all seeds (acc %): '
    info = info + '{:.2f}\n                    (k-sco): '.format(np.average(acc)*100)
    info = info + '{:.3f}\n\nInference time: {:.2f}'.format(np.average(kappa), inference_time * 1000)
    info = info + ' ms per trial\n----------------------------------\n'
    print(info)
    log_write.write(info+'\n')

    # Draw a performance bar chart for all subjects
    draw_performance_barChart(n_sub, acc.mean(1), 'Accuracy')
    draw_performance_barChart(n_sub, kappa.mean(1), 'k-score')
    # Draw confusion matrix for all subjects (average)
    draw_confusion_matrix(cf_matrix.mean((0,1)), 'All', results_path, classes_labels)
    # Close opened file
    log_write.close()

# %% [markdown]
# # Model selection and setup

# %%
#%%
def getModel(model_name, dataset_conf, from_logits = False):

    n_classes = dataset_conf.get('n_classes')
    n_channels = dataset_conf.get('n_channels')
    in_samples = dataset_conf.get('in_samples')

    # Select the model
    if(model_name == 'RockNet'):
        # Train using the proposed ATCNet model: https://ieeexplore.ieee.org/document/9852687
        model = models.RockNet_(
            # Dataset parameters
            n_classes = n_classes,
            in_chans = n_channels,
            in_samples = in_samples,
            # Sliding window (SW) parameter
            n_windows = 5,
            # Attention (AT) block parameter
            attention = 'mha', # Options: None, 'mha','mhla', 'cbam', 'se'
            # Convolutional (CV) block parameters
            eegn_F1 = 16,
            eegn_D = 2,
            eegn_kernelSize = 64,
            eegn_poolSize = 7,
            eegn_dropout = 0.5,
            # Temporal convolutional (TC) block parameters
            tcn_depth = 2,
            tcn_kernelSize = 4,
            tcn_filters = 64,
            tcn_dropout = 0.3,
            tcn_activation='elu',
            )
    elif(model_name == 'RockNetA'):
        model = models.RockNetA(
            n_classes = n_classes,
            in_chans = n_channels,
            in_samples = in_samples,
            n_windows = 5,
            attention = 'mha',
            eegn_F1 = 16,
            eegn_D = 2,
            eegn_kernelSize = 64,
            eegn_poolSize = 7,
            eegn_dropout = 0.5,
            tcn_depth = 2,
            tcn_kernelSize = 4,
            tcn_filters = 32,
            tcn_dropout = 0.3,
            tcn_activation='elu',
        )
    elif(model_name == 'RockNetB'):
        model = models.RockNetB(
            n_classes = n_classes,
            in_chans = n_channels,
            in_samples = in_samples,
            n_windows = 5,
            attention = 'mha',
            eegn_F1 = 16,
            eegn_D = 2,
            eegn_kernelSize = 64,
            eegn_poolSize = 7,
            eegn_dropout = 0.5,
            tcn_depth = 2,
            tcn_kernelSize = 4,
            tcn_filters = 32,
            tcn_dropout = 0.3,
            tcn_activation='elu',
        )
    elif(model_name == 'RockNetC'):
        model = models.RockNetC(
            n_classes = n_classes,
            in_chans = n_channels,
            in_samples = in_samples,
            n_windows = 5,
            attention = 'mha',
            eegn_F1 = 16,
            eegn_D = 2,
            eegn_kernelSize = 64,
            eegn_poolSize = 7,
            eegn_dropout = 0.5,
            tcn_depth = 2,
            tcn_kernelSize = 4,
            tcn_filters = 32,
            tcn_dropout = 0.3,
            tcn_activation='elu',
        )
    elif(model_name == 'RockNetX'):
        model = models.RockNetX(
            n_classes = n_classes,
            in_chans = n_channels,
            in_samples = in_samples,
            n_windows = 5,
            attention = 'transformer',
            eegn_F1 = 16,
            eegn_D = 2,
            eegn_kernelSize = 64,
            eegn_poolSize = 7,
            eegn_dropout = 0.5,
            tcn_depth = 3,
            tcn_kernelSize = 4,
            tcn_filters = 64,
            tcn_dropout = 0.3,
            tcn_activation='gelu',
        )
    elif(model_name == 'RockNetY'):
        model = models.RockNetY(
            n_classes = n_classes,
            in_chans = n_channels,
            in_samples = in_samples,
            n_windows = 5,
            attention = 'mha',
            eegn_F1 = 16,
            eegn_D = 2,
            eegn_kernelSize = 64,
            eegn_poolSize = 7,
            eegn_dropout = 0.5,
            tcn_depth = 2,
            tcn_kernelSize = 4,
            tcn_filters = 32,
            tcn_dropout = 0.3,
            tcn_activation='elu',
        )
    elif(model_name == 'RockNetZ'):
        model = models.RockNetZ(
            n_classes = n_classes,
            in_chans = n_channels,
            in_samples = in_samples,
            n_windows = 5,
            attention = 'mha',
            eegn_F1 = 16,
            eegn_D = 2,
            eegn_kernelSize = 64,
            eegn_poolSize = 7,
            eegn_dropout = 0.5,
            tcn_depth = 2,
            tcn_kernelSize = 4,
            tcn_filters = 32,
            tcn_dropout = 0.3,
            tcn_activation='relu',
        )
    elif(model_name == 'ATCNet'):
        # Train using the proposed ATCNet model: https://ieeexplore.ieee.org/document/9852687
        model = models.ATCNet_(
            # Dataset parameters
            n_classes = n_classes,
            in_chans = n_channels,
            in_samples = in_samples,
            # Sliding window (SW) parameter
            n_windows = 5,
            # Attention (AT) block parameter
            attention = 'mha', # Options: None, 'mha','mhla', 'cbam', 'se'
            # Convolutional (CV) block parameters
            eegn_F1 = 16,
            eegn_D = 2,
            eegn_kernelSize = 64,
            eegn_poolSize = 7,
            eegn_dropout = 0.3,
            # Temporal convolutional (TC) block parameters
            tcn_depth = 2,
            tcn_kernelSize = 4,
            tcn_filters = 32,
            tcn_dropout = 0.3,
            tcn_activation='elu',
            )
    elif(model_name == 'TCNet_Fusion'):
        # Train using TCNet_Fusion: https://doi.org/10.1016/j.bspc.2021.102826
        model = models.TCNet_Fusion(n_classes = n_classes, Chans=n_channels, Samples=in_samples)
    elif(model_name == 'EEGTCNet'):
        # Train using EEGTCNet: https://arxiv.org/abs/2006.00622
        model = models.EEGTCNet(n_classes = n_classes, Chans=n_channels, Samples=in_samples)
    elif(model_name == 'EEGNet'):
        # Train using EEGNet: https://arxiv.org/abs/1611.08024
        model = models.EEGNet_classifier(n_classes = n_classes, Chans=n_channels, Samples=in_samples)
    elif(model_name == 'EEGNeX'):
        # Train using EEGNeX: https://arxiv.org/abs/2207.12369
        model = models.EEGNeX_8_32(n_timesteps = in_samples , n_features = n_channels, n_outputs = n_classes)
    elif(model_name == 'DeepConvNet'):
        # Train using DeepConvNet: https://doi.org/10.1002/hbm.23730
        model = models.DeepConvNet(nb_classes = n_classes , Chans = n_channels, Samples = in_samples)
    elif(model_name == 'ShallowConvNet'):
        # Train using ShallowConvNet: https://doi.org/10.1002/hbm.23730
        model = models.ShallowConvNet(nb_classes = n_classes , Chans = n_channels, Samples = in_samples)
    elif(model_name == 'MBEEG_SENet'):
        # Train using MBEEG_SENet: https://www.mdpi.com/2075-4418/12/4/995
        model = models.MBEEG_SENet(nb_classes = n_classes , Chans = n_channels, Samples = in_samples)

    else:
        raise Exception("'{}' model is not supported yet!".format(model_name))

    return model

# %% [markdown]
# # Run the simulation

# %% [markdown]
# ## Define the run function.

# %%
#%%
def run(signal_preprocessing):
    # Define dataset parameters
    #dataset = 'BCI2a' # Options: 'BCI2a','BCI2b','HGD'
    dataset = 'BCI2b'

    if dataset == 'BCI2a':
        in_samples = 1125
        n_channels = 22
        n_sub = 9
        n_classes = 4
        classes_labels = ['Left hand', 'Right hand','Foot','Tongue']
        data_path = 'dataset/' #os.path.expanduser('~') + '/BCI Competition IV/BCI Competition IV-2a/BCI Competition IV 2a mat/'
    elif dataset == 'HGD':
        in_samples = 1125
        n_channels = 44
        n_sub = 14
        n_classes = 4
        classes_labels = ['Right Hand', 'Left Hand','Rest','Feet']
        data_path = 'dataset/' #os.path.expanduser('~') + '/mne_data/MNE-schirrmeister2017-data/robintibor/high-gamma-dataset/raw/master/data/'
    elif dataset == 'BCI2b':
        in_samples = 750
        n_channels = 3
        n_sub = 9
        n_classes = 2
        classes_labels = ['Left hand', 'Right hand']
        data_path = 'dataset/' #os.path.expanduser('~') + '/BCI Competition IV/BCI Competition IV-2b/BCI Competition IV 2b.mat'
    else:
        raise Exception("'{}' dataset is not supported yet!".format(dataset))

    # Create a folder to store the results of the experiment
    results_path = os.getcwd() + "/results_ATCNet"
    if not  os.path.exists(results_path):
      os.makedirs(results_path)   # Create a new directory if it does not exist

    # Set dataset paramters
    dataset_conf = { 'name': dataset, 'n_classes': n_classes, 'cl_labels': classes_labels,
                    'n_sub': n_sub, 'n_channels': n_channels, 'in_samples': in_samples,
                    'data_path': data_path, 'isStandard': True, 'LOSO': True,
                     'signal_preprocessing':signal_preprocessing}

    # Set training hyperparamters
    train_conf = { 'batch_size': 64, 'epochs': 500, 'patience': 100, 'lr': 0.001,'n_train': 1,
                  'LearnCurves': True, 'from_logits': False, 'model':'ATCNet'}

    # Train the model
    print("Training the model...")
    train(dataset_conf, train_conf, results_path)
    print("Training completed!")

    # Evaluate the model based on the weights saved in the '/results' folder
    model = getModel(train_conf.get('model'), dataset_conf)
    test(model, dataset_conf, results_path)

# %% [markdown]
# ## No preprocessing on EEG.

# %%
run("none")
# Out:
# Training the model...
#
# Training on subject  1
#
#
# Before preprocessing X_train shape is:(1444, 1, 3, 750)
# Before preprocessing X_val shape is:(362, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1444, 1, 3, 750)
# After preprocessing X_val shape is:(362, 1, 3, 750)
# I0000 00:00:1754547269.656603 4024871 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45318 MB memory:  -> device: 0, name: NVIDIA RTX 6000 Ada Generation, pci bus id: 0000:ac:00.0, compute capability: 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754547279.607975 4025086 service.cc:152] XLA service 0x7d2bf8013000 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754547279.608022 4025086 service.cc:160]   StreamExecutor device (0): NVIDIA RTX 6000 Ada Generation, Compute Capability 8.9
# 2025-08-07 08:14:39.993201: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1754547281.806810 4025086 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-08-07 08:14:45.285049: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_62', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-08-07 08:14:45.506715: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_102', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:14:57.540740: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1754547297.754964 4025086 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-08-07 08:15:02.836716: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_102', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:15:15.082573: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:15:18.586399: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_34', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:17:55.123675: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_34', 8 bytes spill stores, 8 bytes spill loads
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step
# Subject: 1   seed 1   time: 3.5 m   valid_acc: 1.0000   valid_loss: 0.011
# Plot Learning Curves .......
# Training on subject  2
#
#
# Before preprocessing X_train shape is:(1468, 1, 3, 750)
# Before preprocessing X_val shape is:(368, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1468, 1, 3, 750)
# After preprocessing X_val shape is:(368, 1, 3, 750)
# 2025-08-07 08:18:43.445576: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:18:50.010064: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_94', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:19:01.153433: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:19:04.318803: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_26', 8 bytes spill stores, 8 bytes spill loads
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step
# 2025-08-07 08:21:40.285438: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_26', 8 bytes spill stores, 8 bytes spill loads
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step
# Subject: 2   seed 1   time: 3.4 m   valid_acc: 0.9837   valid_loss: 0.052
# Plot Learning Curves .......
# Training on subject  3
#
#
# Before preprocessing X_train shape is:(1389, 1, 3, 750)
# Before preprocessing X_val shape is:(348, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1389, 1, 3, 750)
# After preprocessing X_val shape is:(348, 1, 3, 750)
# 2025-08-07 08:22:26.686109: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:22:33.315523: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_94', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:22:44.217712: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:22:47.464216: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_26', 8 bytes spill stores, 8 bytes spill loads
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step
# Subject: 3   seed 1   time: 3.4 m   valid_acc: 0.9943   valid_loss: 0.026
# Plot Learning Curves .......
# Training on subject  4
#
#
# Before preprocessing X_train shape is:(1588, 1, 3, 750)
# Before preprocessing X_val shape is:(398, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1588, 1, 3, 750)
# After preprocessing X_val shape is:(398, 1, 3, 750)
# 2025-08-07 08:26:09.975697: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:26:15.872131: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_94', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:26:28.042795: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step
# Subject: 4   seed 1   time: 3.6 m   valid_acc: 0.9925   valid_loss: 0.029
# Plot Learning Curves .......
# Training on subject  5
#
#
# Before preprocessing X_train shape is:(1548, 1, 3, 750)
# Before preprocessing X_val shape is:(387, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1548, 1, 3, 750)
# After preprocessing X_val shape is:(387, 1, 3, 750)
# 2025-08-07 08:30:05.878442: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:30:23.283683: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step
# Subject: 5   seed 1   time: 3.6 m   valid_acc: 0.9897   valid_loss: 0.037
# Plot Learning Curves .......
# Training on subject  6
#
#
# Before preprocessing X_train shape is:(1387, 1, 3, 750)
# Before preprocessing X_val shape is:(347, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1387, 1, 3, 750)
# After preprocessing X_val shape is:(347, 1, 3, 750)
# 2025-08-07 08:34:01.290378: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:34:07.431874: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_94', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:34:19.035588: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:34:22.199780: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_26', 8 bytes spill stores, 8 bytes spill loads
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step
# Subject: 6   seed 1   time: 3.4 m   valid_acc: 0.9914   valid_loss: 0.025
# Plot Learning Curves .......
# Training on subject  7
#
#
# Before preprocessing X_train shape is:(1533, 1, 3, 750)
# Before preprocessing X_val shape is:(384, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1533, 1, 3, 750)
# After preprocessing X_val shape is:(384, 1, 3, 750)
# 2025-08-07 08:37:47.948814: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:37:53.193543: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_94', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:38:05.890447: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Subject: 7   seed 1   time: 3.5 m   valid_acc: 0.9870   valid_loss: 0.036
# Plot Learning Curves .......
# Training on subject  8
#
#
# Before preprocessing X_train shape is:(1370, 1, 3, 750)
# Before preprocessing X_val shape is:(343, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1370, 1, 3, 750)
# After preprocessing X_val shape is:(343, 1, 3, 750)
# 2025-08-07 08:41:34.901981: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:41:40.998676: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_94', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:41:52.612063: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:41:56.051642: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_26', 8 bytes spill stores, 8 bytes spill loads
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step
# Subject: 8   seed 1   time: 3.4 m   valid_acc: 0.9913   valid_loss: 0.036
# Plot Learning Curves .......
# Training on subject  9
#
#
# Before preprocessing X_train shape is:(1440, 1, 3, 750)
# Before preprocessing X_val shape is:(360, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1440, 1, 3, 750)
# After preprocessing X_val shape is:(360, 1, 3, 750)
# 2025-08-07 08:45:20.202099: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:45:37.001151: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_7', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 08:45:40.586554: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_26', 8 bytes spill stores, 8 bytes spill loads
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step
# Subject: 9   seed 1   time: 3.5 m   valid_acc: 0.9944   valid_loss: 0.027
# Plot Learning Curves .......
# ---------------------------------
# Validation performance (acc %):
# ---------------------------------
#          sub_1   sub_2   sub_3   sub_4   sub_5   sub_6   sub_7   sub_8   sub_9     average
#          -----   -----   -----   -----   -----   -----   -----   -----   -----     -------
# Seed 1:  100.00   98.37   99.43   99.25   98.97   99.14   98.70   99.13   99.44     99.16
# ---------------------------------
# Average acc - all seeds: 99.16 %
#
# Train Time  - all seeds: 34.2 min
# ---------------------------------
#
# Training completed!
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2025-08-07 08:49:09.666958: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_26', 8 bytes spill stores, 8 bytes spill loads
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 624ms/step
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2025-08-07 08:49:30.951880: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_26', 8 bytes spill stores, 8 bytes spill loads
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2025-08-07 08:50:31.895161: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_26', 8 bytes spill stores, 8 bytes spill loads
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 316ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step
#
# ---------------------------------
# Test performance (acc & k-score):
# ---------------------------------
#                   sub_1   sub_2   sub_3   sub_4   sub_5   sub_6   sub_7   sub_8   sub_9     average
#                   -----   -----   -----   -----   -----   -----   -----   -----   -----     -------
# Seed 1: (acc %)   100.00   90.99   98.19   88.89   92.31   99.53   96.67   99.28   99.57     96.16
#         (k-sco)   1.000   0.507   0.658   0.483   0.311   0.921   0.291   0.830   0.921     0.658
# ----------------------------------
# Average - all seeds (acc %): 96.16
#                     (k-sco): 0.658
#
# Inference time: 7.02 ms per trial
# ----------------------------------

# %% [markdown]
# ## RDWT

# %%
run("rdwt")
# Out:
# Training the model...
#
# Training on subject  1
# Before preprocessing X_train shape is:(1444, 1, 3, 750)
# Before preprocessing X_val shape is:(362, 1, 3, 750)
# Lunghezza originale del segnale: (1444, 1, 3, 750)
# Livello 1: coeffs_approx shape (1444, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (1444, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (1444, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (1444, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (1444, 1, 3, 750)
# Lunghezza originale del segnale: (362, 1, 3, 750)
# Livello 1: coeffs_approx shape (362, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (362, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (362, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (362, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (362, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1444, 1, 3, 750)
# After preprocessing X_val shape is:(362, 1, 3, 750)
# 2025-08-07 10:11:08.265068: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 10:11:23.421324: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step
# Subject: 1   seed 1   time: 3.5 m   valid_acc: 1.0000   valid_loss: 0.011
# Plot Learning Curves .......
# Training on subject  2
#
#
# Before preprocessing X_train shape is:(1468, 1, 3, 750)
# Before preprocessing X_val shape is:(368, 1, 3, 750)
# Lunghezza originale del segnale: (1468, 1, 3, 750)
# Livello 1: coeffs_approx shape (1468, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (1468, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (1468, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (1468, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (1468, 1, 3, 750)
# Lunghezza originale del segnale: (368, 1, 3, 750)
# Livello 1: coeffs_approx shape (368, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (368, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (368, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (368, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (368, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1468, 1, 3, 750)
# After preprocessing X_val shape is:(368, 1, 3, 750)
# 2025-08-07 10:15:03.253813: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 10:15:18.553019: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step
# Subject: 2   seed 1   time: 3.6 m   valid_acc: 0.9918   valid_loss: 0.038
# Plot Learning Curves .......
# Training on subject  3
#
#
# Before preprocessing X_train shape is:(1389, 1, 3, 750)
# Before preprocessing X_val shape is:(348, 1, 3, 750)
# Lunghezza originale del segnale: (1389, 1, 3, 750)
# Livello 1: coeffs_approx shape (1389, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (1389, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (1389, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (1389, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (1389, 1, 3, 750)
# Lunghezza originale del segnale: (348, 1, 3, 750)
# Livello 1: coeffs_approx shape (348, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (348, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (348, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (348, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (348, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1389, 1, 3, 750)
# After preprocessing X_val shape is:(348, 1, 3, 750)
# 2025-08-07 10:18:52.276128: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 10:19:07.489143: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step
# Subject: 3   seed 1   time: 3.4 m   valid_acc: 0.9971   valid_loss: 0.038
# Plot Learning Curves .......
# Training on subject  4
#
#
# Before preprocessing X_train shape is:(1588, 1, 3, 750)
# Before preprocessing X_val shape is:(398, 1, 3, 750)
# Lunghezza originale del segnale: (1588, 1, 3, 750)
# Livello 1: coeffs_approx shape (1588, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (1588, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (1588, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (1588, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (1588, 1, 3, 750)
# Lunghezza originale del segnale: (398, 1, 3, 750)
# Livello 1: coeffs_approx shape (398, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (398, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (398, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (398, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (398, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1588, 1, 3, 750)
# After preprocessing X_val shape is:(398, 1, 3, 750)
# 2025-08-07 10:22:34.190129: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 10:22:49.336734: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
# Subject: 4   seed 1   time: 3.6 m   valid_acc: 1.0000   valid_loss: 0.020
# Plot Learning Curves .......
# Training on subject  5
#
#
# Before preprocessing X_train shape is:(1548, 1, 3, 750)
# Before preprocessing X_val shape is:(387, 1, 3, 750)
# Lunghezza originale del segnale: (1548, 1, 3, 750)
# Livello 1: coeffs_approx shape (1548, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (1548, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (1548, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (1548, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (1548, 1, 3, 750)
# Lunghezza originale del segnale: (387, 1, 3, 750)
# Livello 1: coeffs_approx shape (387, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (387, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (387, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (387, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (387, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1548, 1, 3, 750)
# After preprocessing X_val shape is:(387, 1, 3, 750)
# 2025-08-07 10:26:29.137224: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 10:26:44.303702: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step
# Subject: 5   seed 1   time: 3.5 m   valid_acc: 0.9948   valid_loss: 0.041
# Plot Learning Curves .......
# Training on subject  6
#
#
# Before preprocessing X_train shape is:(1387, 1, 3, 750)
# Before preprocessing X_val shape is:(347, 1, 3, 750)
# Lunghezza originale del segnale: (1387, 1, 3, 750)
# Livello 1: coeffs_approx shape (1387, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (1387, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (1387, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (1387, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (1387, 1, 3, 750)
# Lunghezza originale del segnale: (347, 1, 3, 750)
# Livello 1: coeffs_approx shape (347, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (347, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (347, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (347, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (347, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1387, 1, 3, 750)
# After preprocessing X_val shape is:(347, 1, 3, 750)
# 2025-08-07 10:30:21.938099: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 10:30:37.207591: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step
# Subject: 6   seed 1   time: 3.3 m   valid_acc: 0.9914   valid_loss: 0.030
# Plot Learning Curves .......
# Training on subject  7
#
#
# Before preprocessing X_train shape is:(1533, 1, 3, 750)
# Before preprocessing X_val shape is:(384, 1, 3, 750)
# Lunghezza originale del segnale: (1533, 1, 3, 750)
# Livello 1: coeffs_approx shape (1533, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (1533, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (1533, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (1533, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (1533, 1, 3, 750)
# Lunghezza originale del segnale: (384, 1, 3, 750)
# Livello 1: coeffs_approx shape (384, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (384, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (384, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (384, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (384, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1533, 1, 3, 750)
# After preprocessing X_val shape is:(384, 1, 3, 750)
# 2025-08-07 10:34:10.703179: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 10:34:26.302972: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Subject: 7   seed 1   time: 3.6 m   valid_acc: 0.9896   valid_loss: 0.044
# Plot Learning Curves .......
# Training on subject  8
#
#
# Before preprocessing X_train shape is:(1370, 1, 3, 750)
# Before preprocessing X_val shape is:(343, 1, 3, 750)
# Lunghezza originale del segnale: (1370, 1, 3, 750)
# Livello 1: coeffs_approx shape (1370, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (1370, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (1370, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (1370, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (1370, 1, 3, 750)
# Lunghezza originale del segnale: (343, 1, 3, 750)
# Livello 1: coeffs_approx shape (343, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (343, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (343, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (343, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (343, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1370, 1, 3, 750)
# After preprocessing X_val shape is:(343, 1, 3, 750)
# 2025-08-07 10:37:58.135472: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 10:38:13.510412: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step
# Subject: 8   seed 1   time: 3.4 m   valid_acc: 0.9971   valid_loss: 0.034
# Plot Learning Curves .......
# Training on subject  9
#
#
# Before preprocessing X_train shape is:(1440, 1, 3, 750)
# Before preprocessing X_val shape is:(360, 1, 3, 750)
# Lunghezza originale del segnale: (1440, 1, 3, 750)
# Livello 1: coeffs_approx shape (1440, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (1440, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (1440, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (1440, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (1440, 1, 3, 750)
# Lunghezza originale del segnale: (360, 1, 3, 750)
# Livello 1: coeffs_approx shape (360, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (360, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (360, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (360, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (360, 1, 3, 750)
#
#
# After preprocessing X_train shape is:(1440, 1, 3, 750)
# After preprocessing X_val shape is:(360, 1, 3, 750)
# 2025-08-07 10:41:42.418335: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_5', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-08-07 10:41:57.618271: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_reduce_transpose_fusion_7', 8 bytes spill stores, 8 bytes spill loads
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step
# Subject: 9   seed 1   time: 3.4 m   valid_acc: 0.9944   valid_loss: 0.031
# Plot Learning Curves .......
# ---------------------------------
# Validation performance (acc %):
# ---------------------------------
#          sub_1   sub_2   sub_3   sub_4   sub_5   sub_6   sub_7   sub_8   sub_9     average
#          -----   -----   -----   -----   -----   -----   -----   -----   -----     -------
# Seed 1:  100.00   99.18   99.71   100.00   99.48   99.14   98.96   99.71   99.44     99.51
# ---------------------------------
# Average acc - all seeds: 99.51 %
#
# Train Time  - all seeds: 34.3 min
# ---------------------------------
#
# Training completed!
# Lunghezza originale del segnale: (282, 1, 3, 750)
# Livello 1: coeffs_approx shape (282, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (282, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (282, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (282, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (282, 1, 3, 750)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step
# Lunghezza originale del segnale: (111, 1, 3, 750)
# Livello 1: coeffs_approx shape (111, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (111, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (111, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (111, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (111, 1, 3, 750)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 337ms/step
# Lunghezza originale del segnale: (276, 1, 3, 750)
# Livello 1: coeffs_approx shape (276, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (276, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (276, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (276, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (276, 1, 3, 750)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step
# Lunghezza originale del segnale: (45, 1, 3, 750)
# Livello 1: coeffs_approx shape (45, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (45, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (45, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (45, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (45, 1, 3, 750)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Lunghezza originale del segnale: (156, 1, 3, 750)
# Livello 1: coeffs_approx shape (156, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (156, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (156, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (156, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (156, 1, 3, 750)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step
# Lunghezza originale del segnale: (213, 1, 3, 750)
# Livello 1: coeffs_approx shape (213, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (213, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (213, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (213, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (213, 1, 3, 750)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step
# Lunghezza originale del segnale: (270, 1, 3, 750)
# Livello 1: coeffs_approx shape (270, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (270, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (270, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (270, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (270, 1, 3, 750)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step
# Lunghezza originale del segnale: (276, 1, 3, 750)
# Livello 1: coeffs_approx shape (276, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (276, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (276, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (276, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (276, 1, 3, 750)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Lunghezza originale del segnale: (231, 1, 3, 750)
# Livello 1: coeffs_approx shape (231, 1, 3, 750), lo_d shape (12,), hi_d shape (12,)
# Livello 2: coeffs_approx shape (231, 1, 3, 750), lo_d shape (13,), hi_d shape (13,)
# Livello 3: coeffs_approx shape (231, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Livello 4: coeffs_approx shape (231, 1, 3, 750), lo_d shape (14,), hi_d shape (14,)
# Lunghezza del segnale ricostruito: (231, 1, 3, 750)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step
#
# ---------------------------------
# Test performance (acc & k-score):
# ---------------------------------
#                   sub_1   sub_2   sub_3   sub_4   sub_5   sub_6   sub_7   sub_8   sub_9     average
#                   -----   -----   -----   -----   -----   -----   -----   -----   -----     -------
# Seed 1: (acc %)   100.00   95.50   98.91   86.67   92.31   99.53   97.04   99.28   98.70     96.44
#         (k-sco)   1.000   0.684   0.662   0.595   0.311   0.921   0.486   0.796   0.794     0.694
# ----------------------------------
# Average - all seeds (acc %): 96.44
#                     (k-sco): 0.694
#
# Inference time: 4.44 ms per trial
# ----------------------------------
